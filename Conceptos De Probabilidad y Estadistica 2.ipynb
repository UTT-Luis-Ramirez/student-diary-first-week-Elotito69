# %% [markdown]
# **Termino**
# **Probabilidad**
#
# *1- ¿Que se?*
#
#  Se que la probabilidad es una rama matematica que me ayuda a saber el porcentaje de que sucedan ciertos eventos.
#
# *2- ¿Que quiero saber?*
#
#  Me gustaria saber como utilizar la probabilidad a mi favor.
#
# *3- ¿Que aprendi?*
#
#  Aprendi la diferencia de la probabilidad de la estadistica ya que aunque las relaciones entre si la estadistica se enfoca mas en la recolecion de datos y su interpretacion.
#
# **Estaditica**
#
# *1-¿Que se?*
#
#  que la estadistica es la rama que estudia el comportamiento de los datos.
#
# *2-¿Que quiero saber?*
#
#  Me gustaria aprender a darle significado a los datos.
#
# *3-¿Que aprendi?*
#
#  Aprendi su diferencia con la probabilidad ya que la probabilidad se enfoca mas en el porcentaje de que sucedan eventos.
#
# **Dato**
#
# *1-¿Que se?*
#
#  Se que un dato es informacion puede ser un numero, una letra, un conjunto de estas ext. Se diferencian de los eventos por que estos son datos que ya sucedieron.
#
# *2-¿Que quiero saber?*
#
#  Como organizar de manera ma efectiva los datos.
#
# *3-¿Que aprendi?*
#
#  Un dato es cualquier tipo de informacion.
#
# **Evento**
#
# *1-¿Que es?*
#
#  Un evento es un suceso o situacion que aun no ocurre.
#
# *2-¿Que quiero aprender?*
#
#  Distinguir sucesos de los eventos.
#
# *3-¿Que aprendi?*
#
#  Que un evento en un suceso que aun no ocurre pero su probabilidad de ocurrir jamas sera cero.
#
# **Teoria de conjuntos**
#
# *1-¿Que se?*
#
#  Trata de que todo en este universo es parte de un conjunto.
#
# *2-¿Que quiero saber?*
#
#  Saber como utilizar la teoria de conjuntos a mi favor ya que me ayudaria a organizar datos.
#
# *3-¿Que aprendi?*
#
#  Aprendi que es una teoria de conjuntos.
#
# **Axiomas**
#
# *1¿Que se?*
#
#  La verdad nunca en mi vida habia escuchado la palabra axioma.
#
# *2-¿Que quiero saber?*
#
#  Quisiera saber que es un axioma.
#
# *3-¿Que aprendi?*
#
# Que una axioma es una afirmacion que sesga un conjunto.
#
# **Teoria del caos**
#
# *1-¿Que se?*
#
#  Que es una teoria muy hablada por lo interesante que es ya que es como un efecto mariposa.
#
# *2-¿Que quiero saber?*
#
#  Me gustaria saber en que esta relacionado con la probabilidad y la estadistica.
#
# *3-¿Que aprendi?*
#
#  Aprendi que un cambio en una variable o en un dato me podria dar un resultado completamente diferente.
#
# **Falacia**
#
# *1-¿Que se?*
#
#  Que una falacia es una afirmacion negativa.
#
# *2-¿Que quiero saber?*
#
#  Como detactar falacias.
#
# *3-¿Que aprendi?*
#
#  Que una falacia es una afirmacion negativa hasta que demostremos lo contrario.
#
# **Estadistica descriptiva**
#
# *1-¿Que se?*
#
#  Se que la estadistica la interpretacion de un conjunto de datos y su organizacion.
#
# *2-¿Que quiero saber?*
#
#  Me gustaria saber que lo diferencia de la estadistica inferencial.
#
# *3.¿Que aprendi?*
#
#  Aprendi que lo que la diferencia es que la estadistica descritiva es que esta no nos vamos a sacar hipotesis como en la estadistica inferencial, solo describimos los datos. Ademas de que la puedo utilizar en mis finanzas personales y tener una vision mas clara con los datos en mi toma de desiciones.
#
# **Estadistica inferencial**
#
# *1-¿Que se?*
#
#  Se que es un tipo de estadistica.
#
# *2-¿Que quiero saber?*
#
#  Me gustaria saber que la diferencia de la estadistica descriptiva.
#
# *3-¿Que aprendi?*
#
# Aprendi que los tipos de estadistica estan en varios entornos de mi vida cotidiana por increible que paresca estan en las finanzas, la economia e inclusive la medicina sin duda es un tema muy interesante ahora que se que la estadistica sirve para la construccion de IA me gustaria aprender a aplicarla para mas a futuro poder crear mi propia IA.
